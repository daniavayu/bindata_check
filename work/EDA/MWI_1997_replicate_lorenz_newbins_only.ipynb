# %% [markdown]
# ## Resumen
# Este notebook esta destinado a aislar la replica de los componentes new_bins y lorenz_table para Malawi 1997; sirve como espacio de prueba para validar la logica de binning y colapso.

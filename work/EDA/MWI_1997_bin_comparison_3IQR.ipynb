# %% [markdown]
# ## Resumen
# Este notebook replica la comparacion de Malawi 1997 aplicando un tratamiento de outliers altos por regla IQR (3*IQR), para medir su efecto en bins reconstruidos, medias y cola superior.

# %% [markdown]
# # Malawi 1997: Survey Bins vs Global 1000-Bin Distribution, Dropping High IQR Outliers
#
# Objective: repeat the Malawi 1997 bin comparison after dropping high outliers from the disaggregated survey microdata using the rule `welfare_2021ppp_day > Q3 + 3*IQR`.
#
# The PIP mean and the global precomputed 1000-bin mean are kept fixed. The IQR treatment is applied only to the microdata before rebuilding the 1000 equal-population bins.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 80)
pd.set_option("display.max_rows", 80)
pd.set_option("display.float_format", lambda x: f"{x:,.4f}")

# %%
candidates = [
    Path.cwd(),
    Path.cwd().parent,
    Path(r"/Users/danielaavayu/Desktop/World Bank/Bottom Coding"),
]

ROOT = None
for candidate in candidates:
    if (candidate / "01-input" / "pip_1kbins.dta").exists():
        ROOT = candidate
        break

if ROOT is None:
    raise FileNotFoundError("Could not find project root containing 01-input/pip_1kbins.dta")

INPUT = ROOT / "01-input"
OUT = ROOT / "work"

mwi_path = INPUT / "country" / "MWI_1997.dta"
global_bins_path = INPUT / "GlobalDist1000bins_1990_2026_20260324_2021_01_02_PROD.dta"
pip_path = INPUT / "pip_1kbins.dta"

ROOT, mwi_path, global_bins_path, pip_path
# Out:
# (PosixPath('/Users/danielaavayu/Desktop/World Bank/Bottom Coding'),
#  PosixPath('/Users/danielaavayu/Desktop/World Bank/Bottom Coding/01-input/country/MWI_1997.dta'),
#  PosixPath('/Users/danielaavayu/Desktop/World Bank/Bottom Coding/01-input/GlobalDist1000bins_1990_2026_20260324_2021_01_02_PROD.dta'),
#  PosixPath('/Users/danielaavayu/Desktop/World Bank/Bottom Coding/01-input/pip_1kbins.dta'))

# %% [markdown]
# ## 1. Load Malawi 1997 Survey Data
#
# The local Malawi file is microdata. The variable `welfare` is in local currency annual terms, so we convert it to daily 2021 PPP USD to match the global bins.
#
# moneda local anual -> moneda local 2021 -> USD PPP 2021 anual -> USD PPP 2021 diario

# %%
mwi = pd.read_stata(mwi_path, convert_categoricals=False)

mwi[["welfare", "weight", "cpi2021", "icp2021", "year", "survname"]].head()
# Out:
#      welfare     weight  cpi2021  icp2021       year survname
# 0 7,068.1660   187.2218   0.0215 282.0942 1,997.0000    IHS-I
# 1 9,334.1377   374.4435   0.0215 282.0942 1,997.0000    IHS-I
# 2 6,705.0552   748.8870   0.0215 282.0942 1,997.0000    IHS-I
# 3 3,693.1663 1,310.5522   0.0215 282.0942 1,997.0000    IHS-I
# 4 5,462.6602   374.4435   0.0215 282.0942 1,997.0000    IHS-I

# %%
mwi_original = pd.read_stata(mwi_path, convert_categoricals=False)
mwi_original
# Out:
#       countrycode                 hhid     welfare  urban  hsize   wta_hh  \
# 0             MWI  10,177,002,005.0000  7,068.1660      0      1 187.2218
# 1             MWI  10,177,002,008.0000  9,334.1377      0      2 187.2218
# 2             MWI  10,177,002,009.0000  6,705.0552      0      4 187.2218
# 3             MWI  10,177,002,023.0000  3,693.1663      0      7 187.2218
# 4             MWI  10,177,002,025.0000  5,462.6602      0      2 187.2218
# ...           ...                  ...         ...    ...    ...      ...
# 10693         MWI 353,501,039,095.0000  6,549.4707      0      5 114.0455
# 10694         MWI 353,501,039,108.0000  4,532.8530      0      7 114.0455
# 10695         MWI 353,501,039,117.0000 16,584.1094      0      1 114.0455
# 10696         MWI 353,501,039,123.0000 13,787.3555      0      2 114.0455
# 10697         MWI 353,501,039,129.0000 10,360.9072      0      3 114.0455
#
#           weight  fdpindex  nfdpindex     pc_hhdr       subnatid code  \
# 0       187.2218    0.7410     0.7410  9,538.6855   301 – Nsanje  MWI
# 1       374.4435    0.7410     0.7410 12,596.6768   301 – Nsanje  MWI
# 2       748.8870    0.7410     0.7410  9,048.6572   301 – Nsanje  MWI
# 3     1,310.5522    0.7410     0.7410  4,984.0303   301 – Nsanje  MWI
# 4       374.4435    0.7410     0.7410  7,372.0107   301 – Nsanje  MWI
# ...          ...       ...        ...         ...            ...  ...
# 10693   570.2273    1.1240     1.1240  5,826.9316  135 – Chitipa  MWI
# 10694   798.3182    1.1240     1.1240  4,032.7876  135 – Chitipa  MWI
# 10695   114.0455    1.1240     1.1240 14,754.5469  135 – Chitipa  MWI
# 10696   228.0909    1.1240     1.1240 12,266.3311  135 – Chitipa  MWI
# 10697   342.1364    1.1240     1.1240  9,217.8896  135 – Chitipa  MWI
#
#             year survname  cpi_domain  cpi_domain_value  cpi2021_unadj  \
# 0     1,997.0000    IHS-I           1                 1            NaN
# 1     1,997.0000    IHS-I           1                 1            NaN
# 2     1,997.0000    IHS-I           1                 1            NaN
# 3     1,997.0000    IHS-I           1                 1            NaN
# 4     1,997.0000    IHS-I           1                 1            NaN
# ...          ...      ...         ...               ...            ...
# 10693 1,997.0000    IHS-I           1                 1            NaN
# 10694 1,997.0000    IHS-I           1                 1            NaN
# 10695 1,997.0000    IHS-I           1                 1            NaN
# 10696 1,997.0000    IHS-I           1                 1            NaN
# 10697 1,997.0000    IHS-I           1                 1            NaN
#
#        cpi2017_unadj  cpi2011_unadj  cpi2011  cpi2017  cpi2021  icp2011  \
# 0                NaN            NaN   0.1170   0.0314   0.0215  78.7030
# 1                NaN            NaN   0.1170   0.0314   0.0215  78.7030
# 2                NaN            NaN   0.1170   0.0314   0.0215  78.7030
# 3                NaN            NaN   0.1170   0.0314   0.0215  78.7030
# 4                NaN            NaN   0.1170   0.0314   0.0215  78.7030
# ...              ...            ...      ...      ...      ...      ...
# 10693            NaN            NaN   0.1170   0.0314   0.0215  78.7030
# 10694            NaN            NaN   0.1170   0.0314   0.0215  78.7030
# 10695            NaN            NaN   0.1170   0.0314   0.0215  78.7030
# 10696            NaN            NaN   0.1170   0.0314   0.0215  78.7030
# 10697            NaN            NaN   0.1170   0.0314   0.0215  78.7030
#
#        icp2017  icp2021  comparability  cpi_replication cpi_domain_var  \
# 0     241.9305 282.0942              0               -9
# 1     241.9305 282.0942              0               -9
# 2     241.9305 282.0942              0               -9
# 3     241.9305 282.0942              0               -9
# 4     241.9305 282.0942              0               -9
# ...        ...      ...            ...              ...            ...
# 10693 241.9305 282.0942              0               -9
# 10694 241.9305 282.0942              0               -9
# 10695 241.9305 282.0942              0               -9
# 10696 241.9305 282.0942              0               -9
# 10697 241.9305 282.0942              0               -9
#
#        icpreplication icpdomain_var  icpdomain_value  comparable  cpi2005  \
# 0                   1                              1           0      NaN
# 1                   1                              1           0      NaN
# 2                   1                              1           0      NaN
# 3                   1                              1           0      NaN
# 4                   1                              1           0      NaN
# ...               ...           ...              ...         ...      ...
# 10693               1                              1           0      NaN
# 10694               1                              1           0      NaN
# 10695               1                              1           0      NaN
# 10696               1                              1           0      NaN
# 10697               1                              1           0      NaN
#
#        icp2005 cpi_data_level  cpi2011_SM26  cpi2017_SM26  cpi2021_SM26  \
# 0          NaN              2        0.1170        0.0314        0.0215
# 1          NaN              2        0.1170        0.0314        0.0215
# 2          NaN              2        0.1170        0.0314        0.0215
# 3          NaN              2        0.1170        0.0314        0.0215
# 4          NaN              2        0.1170        0.0314        0.0215
# ...        ...            ...           ...           ...           ...
# 10693      NaN              2        0.1170        0.0314        0.0215
# 10694      NaN              2        0.1170        0.0314        0.0215
# 10695      NaN              2        0.1170        0.0314        0.0215
# 10696      NaN              2        0.1170        0.0314        0.0215
# 10697      NaN              2        0.1170        0.0314        0.0215
#
#        icp2011_SM26  icp2017_SM26  icp2021_SM26
# 0           78.7030      241.9305      282.0942
# 1           78.7030      241.9305      282.0942
# 2           78.7030      241.9305      282.0942
# 3           78.7030      241.9305      282.0942
# 4           78.7030      241.9305      282.0942
# ...             ...           ...           ...
# 10693       78.7030      241.9305      282.0942
# 10694       78.7030      241.9305      282.0942
# 10695       78.7030      241.9305      282.0942
# 10696       78.7030      241.9305      282.0942
# 10697       78.7030      241.9305      282.0942
#
# [10698 rows x 41 columns]

# %%
tdf = mwi.sort_values("welfare", ascending=False)
tdf.head(10)
# Out:
#       countrycode                 hhid          welfare  urban  hsize  \
# 7694          MWI 252,563,005,049.0000 118,420,360.0000      0      2
# 10462         MWI 343,406,801,173.0000  27,006,552.0000      0      1
# 9843          MWI 313,110,008,237.0000   1,204,712.3750      1      2
# 7269          MWI 242,418,065,255.0000     981,653.6250      1      7
# 9812          MWI 313,109,004,249.0000     713,340.8750      1      1
# 7379          MWI 242,425,031,321.0000     428,542.3125      1      1
# 7120          MWI 242,403,134,158.0000     374,757.7500      1      5
# 1503          MWI  50,514,195,012.0000     346,888.0312      1      1
# 1487          MWI  50,513,188,055.0000     345,174.0938      1      5
# 7124          MWI 242,403,135,043.0000     288,622.6250      1      1
#
#         wta_hh     weight  fdpindex  nfdpindex      pc_hhdr  \
# 7694  162.1831   324.3661    0.9230     0.9230 321,180.0625
# 10462 148.4000   148.4000    1.1240     1.1240 321,180.0625
# 9843   75.5106   151.0213    2.2210     2.2210 321,180.0625
# 7269  261.0616 1,827.4313    2.2210     2.2210 321,180.0625
# 9812   75.5106    75.5106    2.2210     2.2210 321,180.0625
# 7379  261.0616   261.0616    2.2210     2.2210 192,950.1719
# 7120  261.0616 1,305.3081    2.2210     2.2210 168,733.7969
# 1503  196.6864   196.6864    2.2210     2.2210 156,185.5156
# 1487  196.6864   983.4323    2.2210     2.2210 155,413.8281
# 7124  261.0616   261.0616    2.2210     2.2210 129,951.6562
#
#                   subnatid code       year survname  cpi_domain  \
# 7694         225 – Mchinji  MWI 1,997.0000    IHS-I           1
# 10462        134 – Karonga  MWI 1,997.0000    IHS-I           1
# 9843      131 – Mzuzu City  MWI 1,997.0000    IHS-I           1
# 7269   224 – Lilongwe City  MWI 1,997.0000    IHS-I           1
# 9812      131 – Mzuzu City  MWI 1,997.0000    IHS-I           1
# 7379   224 – Lilongwe City  MWI 1,997.0000    IHS-I           1
# 7120   224 – Lilongwe City  MWI 1,997.0000    IHS-I           1
# 1503   305 – Blantyre City  MWI 1,997.0000    IHS-I           1
# 1487   305 – Blantyre City  MWI 1,997.0000    IHS-I           1
# 7124   224 – Lilongwe City  MWI 1,997.0000    IHS-I           1
#
#        cpi_domain_value  cpi2021_unadj  cpi2017_unadj  cpi2011_unadj  cpi2011  \
# 7694                  1            NaN            NaN            NaN   0.1170
# 10462                 1            NaN            NaN            NaN   0.1170
# 9843                  1            NaN            NaN            NaN   0.1170
# 7269                  1            NaN            NaN            NaN   0.1170
# 9812                  1            NaN            NaN            NaN   0.1170
# 7379                  1            NaN            NaN            NaN   0.1170
# 7120                  1            NaN            NaN            NaN   0.1170
# 1503                  1            NaN            NaN            NaN   0.1170
# 1487                  1            NaN            NaN            NaN   0.1170
# 7124                  1            NaN            NaN            NaN   0.1170
#
#        cpi2017  cpi2021  icp2011  icp2017  icp2021  comparability  \
# 7694    0.0314   0.0215  78.7030 241.9305 282.0942              0
# 10462   0.0314   0.0215  78.7030 241.9305 282.0942              0
# 9843    0.0314   0.0215  78.7030 241.9305 282.0942              0
# 7269    0.0314   0.0215  78.7030 241.9305 282.0942              0
# 9812    0.0314   0.0215  78.7030 241.9305 282.0942              0
# 7379    0.0314   0.0215  78.7030 241.9305 282.0942              0
# 7120    0.0314   0.0215  78.7030 241.9305 282.0942              0
# 1503    0.0314   0.0215  78.7030 241.9305 282.0942              0
# 1487    0.0314   0.0215  78.7030 241.9305 282.0942              0
# 7124    0.0314   0.0215  78.7030 241.9305 282.0942              0
#
#        cpi_replication cpi_domain_var  icpreplication icpdomain_var  \
# 7694                -9                              1
# 10462               -9                              1
# 9843                -9                              1
# 7269                -9                              1
# 9812                -9                              1
# 7379                -9                              1
# 7120                -9                              1
# 1503                -9                              1
# 1487                -9                              1
# 7124                -9                              1
#
#        icpdomain_value  comparable  cpi2005  icp2005 cpi_data_level  \
# 7694                 1           0      NaN      NaN              2
# 10462                1           0      NaN      NaN              2
# 9843                 1           0      NaN      NaN              2
# 7269                 1           0      NaN      NaN              2
# 9812                 1           0      NaN      NaN              2
# 7379                 1           0      NaN      NaN              2
# 7120                 1           0      NaN      NaN              2
# 1503                 1           0      NaN      NaN              2
# 1487                 1           0      NaN      NaN              2
# 7124                 1           0      NaN      NaN              2
#
#        cpi2011_SM26  cpi2017_SM26  cpi2021_SM26  icp2011_SM26  icp2017_SM26  \
# 7694         0.1170        0.0314        0.0215       78.7030      241.9305
# 10462        0.1170        0.0314        0.0215       78.7030      241.9305
# 9843         0.1170        0.0314        0.0215       78.7030      241.9305
# 7269         0.1170        0.0314        0.0215       78.7030      241.9305
# 9812         0.1170        0.0314        0.0215       78.7030      241.9305
# 7379         0.1170        0.0314        0.0215       78.7030      241.9305
# 7120         0.1170        0.0314        0.0215       78.7030      241.9305
# 1503         0.1170        0.0314        0.0215       78.7030      241.9305
# 1487         0.1170        0.0314        0.0215       78.7030      241.9305
# 7124         0.1170        0.0314        0.0215       78.7030      241.9305
#
#        icp2021_SM26
# 7694       282.0942
# 10462      282.0942
# 9843       282.0942
# 7269       282.0942
# 9812       282.0942
# 7379       282.0942
# 7120       282.0942
# 1503       282.0942
# 1487       282.0942
# 7124       282.0942

# %%
cpi2021 = mwi["cpi2021"].dropna().iloc[0]
icp2021 = mwi["icp2021"].dropna().iloc[0]

mwi = mwi[["welfare", "weight"]].dropna().copy()
mwi = mwi[mwi["weight"] > 0].copy()

mwi["welfare_2021ppp_day"] = mwi["welfare"] / (cpi2021 * icp2021 * 365)

mwi[["welfare", "welfare_2021ppp_day", "weight"]].describe()
# Out:
#                welfare  welfare_2021ppp_day      weight
# count      10,698.0000          10,698.0000 10,698.0000
# mean       23,388.5117              10.5538    903.5939
# std     1,174,402.6250             529.9362    608.4971
# min           448.9857               0.2026     59.5042
# 25%         3,988.1519               1.7996    459.9083
# 50%         6,036.3799               2.7238    778.1250
# 75%         9,712.1763               4.3825  1,185.8865
# max   118,420,360.0000          53,435.8750  6,765.0000

# %% [markdown]
# ## IQR Treatment: Drop High Outliers From Microdata
#
# This step saves the original converted microdata as `mwi_original`, identifies observations above `Q3 + 3*IQR`, and then replaces `mwi` with the filtered dataset. All subsequent bin reconstruction uses the filtered microdata.

# %%
mwi_original = mwi.copy()

value_col = "welfare_2021ppp_day"
weight_col = "weight"

q1 = mwi_original[value_col].quantile(0.25)
q3 = mwi_original[value_col].quantile(0.75)
iqr = q3 - q1
upper_fence_3iqr = q3 + 3 * iqr

mwi_iqr_outliers = mwi_original[mwi_original[value_col] > upper_fence_3iqr].copy()
mwi_no_iqr_outliers = mwi_original[mwi_original[value_col] <= upper_fence_3iqr].copy()

# From this point onward, the notebook rebuilds bins using the filtered microdata.
mwi = mwi_no_iqr_outliers.copy()

iqr_summary = pd.DataFrame({
    "stat": [
        "Q1",
        "Q3",
        "IQR",
        "Upper fence: Q3 + 3*IQR",
        "Original observations",
        "Observations after dropping high outliers",
        "Observations dropped",
        "Original weighted population",
        "Weighted population after dropping high outliers",
        "Weighted population dropped",
    ],
    "value": [
        q1,
        q3,
        iqr,
        upper_fence_3iqr,
        len(mwi_original),
        len(mwi),
        len(mwi_iqr_outliers),
        mwi_original[weight_col].sum(),
        mwi[weight_col].sum(),
        mwi_iqr_outliers[weight_col].sum(),
    ],
})

iqr_summary
# Out:
#                                                stat          value
# 0                                                Q1         1.7996
# 1                                                Q3         4.3825
# 2                                               IQR         2.5829
# 3                           Upper fence: Q3 + 3*IQR        12.1312
# 4                             Original observations    10,698.0000
# 5         Observations after dropping high outliers    10,223.0000
# 6                              Observations dropped       475.0000
# 7                      Original weighted population 9,666,648.0000
# 8  Weighted population after dropping high outliers 9,341,226.0000
# 9                       Weighted population dropped   325,422.8438

# %%
mwi_iqr_outliers.sort_values(value_col, ascending=False).head(30)
# Out:
#                welfare     weight  welfare_2021ppp_day
# 7694  118,420,360.0000   324.3661          53,435.8750
# 10462  27,006,552.0000   148.4000          12,186.4072
# 9843    1,204,712.3750   151.0213             543.6131
# 7269      981,653.6250 1,827.4313             442.9603
# 9812      713,340.8750    75.5106             321.8872
# 7379      428,542.3125   261.0616             193.3750
# 7120      374,757.7500 1,305.3081             169.1053
# 1503      346,888.0312   196.6864             156.5294
# 1487      345,174.0938   983.4323             155.7560
# 7124      288,622.6250   261.0616             130.2378
# 1289      283,198.5625   786.7458             127.7902
# 7123      247,765.1250 1,044.2465             111.8013
# 1208      247,009.3125   786.7458             111.4602
# 1211      223,579.6719   983.4323             100.8879
# 1429      217,735.0781   590.0593              98.2505
# 1425      211,133.2656   196.6864              95.2715
# 1488      207,069.0000   196.6864              93.4376
# 1451      200,491.5781 1,180.1187              90.4696
# 1291      197,297.6875 1,180.1187              89.0284
# 7397      190,950.7188 1,044.2465              86.1644
# 7128      190,195.9062   522.1232              85.8238
# 7129      184,660.8125   783.1848              83.3261
# 1485      180,629.8594 1,180.1187              81.5072
# 1484      179,384.3594   393.3729              80.9452
# 7422      178,921.2188 1,044.2465              80.7362
# 7219      178,334.8438   522.1232              80.4716
# 7226      171,439.1875   522.1232              77.3600
# 7106      170,123.3594 1,305.3081              76.7663
# 1445      165,378.9062 1,180.1187              74.6254
# 1448      163,834.4375   983.4323              73.9285

# %% [markdown]
# ## 2. Reconstruct 1000 Equal-Population Bins From the Survey
#
# The global file has 1000 bins. Each bin is approximately 0.1 percent of the weighted population. The function below sorts observations by welfare and uses survey weights to create 1000 equally weighted bins.

# %%
def weighted_equal_bins(df, value_col, weight_col, n_bins=1000):
    # Create equal-population weighted bins and return the weighted mean welfare in each bin.
    d = df[[value_col, weight_col]].dropna().copy()
    d = d[d[weight_col] > 0].sort_values(value_col).reset_index(drop=True)

    values = d[value_col].to_numpy(dtype=float)
    weights = d[weight_col].to_numpy(dtype=float)

    total_weight = weights.sum()
    bin_weight = total_weight / n_bins

    out = []
    i = 0
    remaining_weight_current_obs = weights[0]

    for b in range(1, n_bins + 1):
        needed = bin_weight
        numerator = 0.0
        denominator = 0.0

        while needed > 1e-10 and i < len(values):
            take = min(remaining_weight_current_obs, needed)

            numerator += values[i] * take
            denominator += take

            needed -= take
            remaining_weight_current_obs -= take

            if remaining_weight_current_obs <= 1e-10:
                i += 1
                if i < len(values):
                    remaining_weight_current_obs = weights[i]

        out.append({
            "quantile": float(b),
            "survey_bin_welf": numerator / denominator,
            "survey_bin_weight": denominator,
        })

    return pd.DataFrame(out)

# %%
mwi_survey_bins = weighted_equal_bins(
    mwi,
    value_col="welfare_2021ppp_day",
    weight_col="weight",
    n_bins=1000,
)

mwi_survey_bins.head()
mwi_survey_bins
# Out:
#       quantile  survey_bin_welf  survey_bin_weight
# 0       1.0000           0.2990         9,341.2252
# 1       2.0000           0.3532         9,341.2252
# 2       3.0000           0.3938         9,341.2252
# 3       4.0000           0.4150         9,341.2252
# 4       5.0000           0.4350         9,341.2252
# ..         ...              ...                ...
# 995   996.0000          11.3341         9,341.2252
# 996   997.0000          11.5508         9,341.2252
# 997   998.0000          11.7155         9,341.2252
# 998   999.0000          11.9012         9,341.2252
# 999 1,000.0000          12.0698         9,341.2252
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 3. Load Malawi 1997 From the Global 1000-Bin File
#
# The global file is large, so this reads it in chunks and keeps only Malawi 1997.

# %%
chunks = []

for chunk in pd.read_stata(
    global_bins_path,
    columns=["code", "year", "quantile", "welf", "pop"],
    chunksize=500_000,
):
    chunk["year"] = chunk["year"].astype(int)

    keep = (
        (chunk["code"] == "MWI") &
        (chunk["year"] == 1997)
    )

    if keep.any():
        chunks.append(chunk.loc[keep].copy())

mwi_global_bins = pd.concat(chunks, ignore_index=True)

mwi_global_bins
# Out:
#     code  year   quantile       welf    pop
# 0    MWI  1997     1.0000     0.3140 0.0106
# 1    MWI  1997     2.0000     0.3540 0.0106
# 2    MWI  1997     3.0000     0.3939 0.0106
# 3    MWI  1997     4.0000     0.4164 0.0106
# 4    MWI  1997     5.0000     0.4354 0.0106
# ..   ...   ...        ...        ...    ...
# 995  MWI  1997   996.0000    46.8856 0.0106
# 996  MWI  1997   997.0000    56.9003 0.0106
# 997  MWI  1997   998.0000    70.5454 0.0106
# 998  MWI  1997   999.0000    82.7385 0.0106
# 999  MWI  1997 1,000.0000 1,296.4863 0.0106
#
# [1000 rows x 5 columns]

# %%
mwi.sort_values("welfare_2021ppp_day", ascending=False).head(10)
# Out:
#          welfare     weight  welfare_2021ppp_day
# 4203 26,830.3242 2,738.5730              12.1069
# 1400 26,825.8340   983.4323              12.1049
# 2475 26,791.9922   238.0170              12.0896
# 7263 26,776.5938 1,305.3081              12.0826
# 7415 26,775.1270   261.0616              12.0820
# 8384 26,721.5254   563.0569              12.0578
# 1202 26,720.5020   590.0593              12.0573
# 8043 26,712.9297   434.7527              12.0539
# 1185 26,652.1504   393.3729              12.0265
# 8200 26,602.1504   652.1290              12.0039

# %% [markdown]
# ## 4. Compare Survey-Reconstructed Bins With Global Bins

# %%
mwi_bin_comparison = mwi_survey_bins.merge(
    mwi_global_bins[["quantile", "welf", "pop"]],
    on="quantile",
    how="left",
)

mwi_bin_comparison = mwi_bin_comparison.rename(
    columns={"welf": "global_bin_welf", "pop": "global_bin_pop"}
)

mwi_bin_comparison["diff_survey_minus_global"] = (
    mwi_bin_comparison["survey_bin_welf"] -
    mwi_bin_comparison["global_bin_welf"]
)

mwi_bin_comparison["ratio_survey_global"] = (
    mwi_bin_comparison["survey_bin_welf"] /
    mwi_bin_comparison["global_bin_welf"]
)

mwi_bin_comparison
# Out:
#       quantile  survey_bin_welf  survey_bin_weight  global_bin_welf  \
# 0       1.0000           0.2990         9,341.2252           0.3140
# 1       2.0000           0.3532         9,341.2252           0.3540
# 2       3.0000           0.3938         9,341.2252           0.3939
# 3       4.0000           0.4150         9,341.2252           0.4164
# 4       5.0000           0.4350         9,341.2252           0.4354
# ..         ...              ...                ...              ...
# 995   996.0000          11.3341         9,341.2252          46.8856
# 996   997.0000          11.5508         9,341.2252          56.9003
# 997   998.0000          11.7155         9,341.2252          70.5454
# 998   999.0000          11.9012         9,341.2252          82.7385
# 999 1,000.0000          12.0698         9,341.2252       1,296.4863
#
#      global_bin_pop  diff_survey_minus_global  ratio_survey_global
# 0            0.0106                   -0.0150               0.9522
# 1            0.0106                   -0.0008               0.9978
# 2            0.0106                   -0.0001               0.9998
# 3            0.0106                   -0.0013               0.9968
# 4            0.0106                   -0.0004               0.9990
# ..              ...                       ...                  ...
# 995          0.0106                  -35.5515               0.2417
# 996          0.0106                  -45.3495               0.2030
# 997          0.0106                  -58.8299               0.1661
# 998          0.0106                  -70.8374               0.1438
# 999          0.0106               -1,284.4165               0.0093
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## 5. Summary by Bin Ranges
#
# This table checks whether the lower, middle, and upper parts of the distribution match. If the problem is mostly the top bin, the ratios should be close to 1 for most bins and much larger for bin 1000.

# %%
summary_rows = []

for lo, hi in [(1, 10), (1, 50), (1, 100), (101, 900), (901, 990), (991, 999), (1000, 1000)]:
    sub = mwi_bin_comparison[
        (mwi_bin_comparison["quantile"] >= lo) &
        (mwi_bin_comparison["quantile"] <= hi)
    ]

    summary_rows.append({
        "bins": f"{lo}-{hi}",
        "survey_mean_of_bins": sub["survey_bin_welf"].mean(),
        "global_mean_of_bins": sub["global_bin_welf"].mean(),
        "avg_diff": sub["diff_survey_minus_global"].mean(),
        "avg_ratio": sub["ratio_survey_global"].mean(),
    })

bin_range_summary = pd.DataFrame(summary_rows)
bin_range_summary
# Out:
#         bins  survey_mean_of_bins  global_mean_of_bins    avg_diff  avg_ratio
# 0       1-10               0.4348               0.4374     -0.0026     0.9930
# 1       1-50               0.7052               0.7079     -0.0027     0.9959
# 2      1-100               0.8868               0.8884     -0.0016     0.9977
# 3    101-900               2.5404               2.6443     -0.1038     0.9733
# 4    901-990               7.2256              10.5199     -3.2943     0.7316
# 5    991-999              11.1414              46.4749    -35.3335     0.2720
# 6  1000-1000              12.0698           1,296.4863 -1,284.4165     0.0093

# %% [markdown]
# ## 6. Compare Overall Means
# PIP mean vs mean reconstructed from the global 1000-bin data.

# %%
pip = pd.read_stata(pip_path)
pip["year"] = pip["year"].astype(int)

mwi_pip_row = pip[(pip["country_code"] == "MWI") & (pip["year"] == 1997)].iloc[0]

survey_mean_original = (
    mwi_original["welfare_2021ppp_day"] * mwi_original["weight"]
).sum() / mwi_original["weight"].sum()

survey_mean_iqr_filtered = (
    mwi["welfare_2021ppp_day"] * mwi["weight"]
).sum() / mwi["weight"].sum()

rebuilt_1kbins_mean_iqr_filtered = (
    mwi_survey_bins["survey_bin_welf"] * mwi_survey_bins["survey_bin_weight"]
).sum() / mwi_survey_bins["survey_bin_weight"].sum()

mean_comparison = pd.DataFrame({
    "source": [
        "Survey microdata, original",
        "Survey microdata, after dropping > Q3 + 3*IQR",
        "Rebuilt 1000-bin mean, after dropping > Q3 + 3*IQR",
        "PIP mean",
        "Global 1000-bin mean",
    ],
    "mean_welfare": [
        survey_mean_original,
        survey_mean_iqr_filtered,
        rebuilt_1kbins_mean_iqr_filtered,
        mwi_pip_row["mean"],
        mwi_pip_row["mean_1kbins"],
    ],
})

mean_comparison["difference_vs_pip"] = mean_comparison["mean_welfare"] - mwi_pip_row["mean"]
mean_comparison["pct_difference_vs_pip"] = mean_comparison["difference_vs_pip"] / mwi_pip_row["mean"]

mean_comparison
# Out:
#                                               source  mean_welfare  \
# 0                         Survey microdata, original        5.7796
# 1      Survey microdata, after dropping > Q3 + 3*IQR        2.8837
# 2  Rebuilt 1000-bin mean, after dropping > Q3 + 3...        2.8837
# 3                                           PIP mean        5.7240
# 4                               Global 1000-bin mean        4.8658
#
#    difference_vs_pip  pct_difference_vs_pip
# 0             0.0556                 0.0097
# 1            -2.8403                -0.4962
# 2            -2.8403                -0.4962
# 3             0.0000                 0.0000
# 4            -0.8582                -0.1499

# %% [markdown]
# ## 7. Graphs

# %%
fig, ax = plt.subplots(figsize=(12, 5))

ax.plot(
    mwi_bin_comparison["quantile"],
    mwi_bin_comparison["survey_bin_welf"],
    label="Survey reconstructed bins",
    linewidth=1.5,
)

ax.plot(
    mwi_bin_comparison["quantile"],
    mwi_bin_comparison["global_bin_welf"],
    label="Global 1000-bin data",
    linewidth=1.5,
    linestyle="--",
)

ax.set_title("Malawi 1997: survey-reconstructed bins vs global 1000-bin data")
ax.set_xlabel("Bin / quantile")
ax.set_ylabel("Mean welfare, 2021 PPP USD per person per day")
ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))

ax.plot(
    mwi_bin_comparison["quantile"],
    mwi_bin_comparison["survey_bin_welf"],
    label="Survey reconstructed bins",
    linewidth=1.5,
)

ax.plot(
    mwi_bin_comparison["quantile"],
    mwi_bin_comparison["global_bin_welf"],
    label="Global 1000-bin data",
    linewidth=1.5,
    linestyle="--",
)

ax.set_yscale("log")
ax.set_title("Malawi 1997: bin means comparison, log scale")
ax.set_xlabel("Bin / quantile")
ax.set_ylabel("Mean welfare, log scale")
ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))

ax.plot(
    mwi_bin_comparison["quantile"],
    mwi_bin_comparison["diff_survey_minus_global"],
    linewidth=1.5,
)

ax.axhline(0, color="black", linewidth=1)
ax.set_title("Malawi 1997: difference between survey bins and global bins")
ax.set_xlabel("Bin / quantile")
ax.set_ylabel("Survey bin mean - global bin mean")

plt.tight_layout()
plt.show()

# %%
top_zoom = mwi_bin_comparison[mwi_bin_comparison["quantile"] >= 950]

fig, ax = plt.subplots(figsize=(12, 5))

ax.plot(
    top_zoom["quantile"],
    top_zoom["survey_bin_welf"],
    label="Survey reconstructed bins",
    marker="o",
    markersize=3,
    linewidth=1.5,
)

ax.plot(
    top_zoom["quantile"],
    top_zoom["global_bin_welf"],
    label="Global 1000-bin data",
    marker="o",
    markersize=3,
    linewidth=1.5,
    linestyle="--",
)

ax.set_title("Malawi 1997: zoom on top bins")
ax.set_xlabel("Bin / quantile")
ax.set_ylabel("Mean welfare, 2021 PPP USD per person per day")
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Export IQR Outputs

# %%
iqr_summary.to_csv(OUT / "MWI_1997_iqr_summary.csv", index=False)
mean_comparison.to_csv(OUT / "MWI_1997_iqr_mean_comparison.csv", index=False)
mwi_bin_comparison.to_csv(OUT / "MWI_1997_iqr_bins_vs_global.csv", index=False)
mwi_iqr_outliers.to_csv(OUT / "MWI_1997_iqr_dropped_outliers.csv", index=False)

OUT
# Out:
# PosixPath('/Users/danielaavayu/Desktop/World Bank/Bottom Coding/work')

# %%
import pandas as pd
df = pd.read_stata("C:\\Users\\wb661551\\OneDrive - WBG\\Desktop\\Internship\\Bottom Censoring\\bindata_check\\corrected_method\\01-processing\\raw\\BEL_2000.dta")

# %%
df
# Out:
#     code    bins       welfare      weight  share    year       survname  \
# 0    BEL     1.0  0.000000e+00  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# 1    BEL     2.0  0.000000e+00  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# 2    BEL     3.0  6.932757e+02  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# 3    BEL     4.0  2.389513e+04  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# 4    BEL     5.0  2.520006e+04  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# ..   ...     ...           ...         ...    ...     ...            ...
# 995  BEL   996.0  2.493523e+06  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# 996  BEL   997.0  2.748475e+06  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# 997  BEL   998.0  3.116165e+06  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# 998  BEL   999.0  4.661206e+06  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
# 999  BEL  1000.0  3.433241e+07  7322.64502    0.1  2000.0  PSBH-ECHP-LIS
#
#     cpi_domain  cpi_domain_value  cpi2021_unadj  ...  comparable  cpi2005  \
# ...

# %%
print(list(df.columns))
